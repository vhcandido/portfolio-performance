# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
#https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
print(X)
print(Y)
print(Z)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3, cmap=cm.coolwarm)

cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm) # contour floor
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm) # contour <-
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm) # contour ->

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# [[-30.  -29.5 -29.  ...  28.5  29.   29.5]
#  [-30.  -29.5 -29.  ...  28.5  29.   29.5]
#  [-30.  -29.5 -29.  ...  28.5  29.   29.5]
#  ...
#  [-30.  -29.5 -29.  ...  28.5  29.   29.5]
#  [-30.  -29.5 -29.  ...  28.5  29.   29.5]
#  [-30.  -29.5 -29.  ...  28.5  29.   29.5]]
# [[-30.  -30.  -30.  ... -30.  -30.  -30. ]
#  [-29.5 -29.5 -29.5 ... -29.5 -29.5 -29.5]
#  [-29.  -29.  -29.  ... -29.  -29.  -29. ]
#  ...
#  [ 28.5  28.5  28.5 ...  28.5  28.5  28.5]
#  [ 29.   29.   29.  ...  29.   29.   29. ]
#  [ 29.5  29.5  29.5 ...  29.5  29.5  29.5]]
# [[-0.00982064 -0.0113957  -0.01319036 ... -0.01522953 -0.01319036
#   -0.0113957 ]
#  [-0.0113957  -0.01322338 -0.01530587 ... -0.01767209 -0.01530587
#   -0.01322338]
#  [-0.01319036 -0.01530587 -0.01771632 ... -0.02045518 -0.01771632
#   -0.01530587]
#  ...
#  [-0.01200234 -0.01414685 -0.01660867 ...  0.02918791  0.03019517
#    0.03085725]
# ...

# %%
from mpl_toolkits.mplot3d import axes3d

#melted = load_r.get_melted_balance()
#X, Y, Z = melted.Var1.values.reshape(50,50), melted.Var2.values.reshape(50,50), r

X, Y = np.meshgrid(*[np.arange(s) for s in shape[1:]])
Z = balance[-1]


fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z,
                alpha=.7, cmap=plt.cm.jet, antialiased=True,
                vmin=zlim[0], vmax=zlim[1],
                linewidth=.5,rstride=2, cstride=2)

fig.colorbar(surf, shrink=0.5, aspect=5)

#cset = ax.contour(X, Y, Z, zdir='z', offset=.8, cmap=plt.cm.coolwarm) # contour floor
#cset = ax.contour(X, Y, Z, zdir='x', offset=0, cmap=plt.cm.coolwarm) # contour <-
#cset = ax.contour(X, Y, Z, zdir='y', offset=50, cmap=plt.cm.coolwarm) # contour ->
